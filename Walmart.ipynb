# %% [markdown]
# <a href="https://colab.research.google.com/github/ag0466154-cpu/Estadistica2025B/blob/main/Walmart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Vaciado de datos

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/ag0466154-cpu/Estadistica2025B/refs/heads/main/Walmart_Sales.csv"
df = pd.read_csv(url)
df = df.dropna()
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# 2     211.289143         8.106
# 3     211.319643         8.106
# 4     211.350143         8.106
# ...          ...           ...
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667
#
# [6435 rows x 8 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y')
df
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-02-05    1643690.90             0        42.31       2.572
# 1         1 2010-02-12    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-03-05    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-10-05     733455.07             0        64.89       3.985
# 6432     45 2012-10-12     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# 2     211.289143         8.106
# 3     211.319643         8.106
# 4     211.350143         8.106
# ...          ...           ...
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667
#
# [6435 rows x 8 columns]

# %%
df = df.sort_index()

# %%
df = df[df['Store'] == 11]
df
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 1430     11 2010-02-05    1528008.64             0        46.04       2.572
# 1431     11 2010-02-12    1574684.08             1        48.01       2.548
# 1432     11 2010-02-19    1503298.70             0        48.30       2.514
# 1433     11 2010-02-26    1336404.65             0        52.79       2.561
# 1434     11 2010-03-05    1426622.65             0        53.96       2.625
# ...     ...        ...           ...           ...          ...         ...
# 1568     11 2012-09-28    1227430.73             0        77.67       3.666
# 1569     11 2012-10-05    1422794.26             0        73.37       3.617
# 1570     11 2012-10-12    1311965.09             0        69.94       3.601
# 1571     11 2012-10-19    1232073.18             0        73.77       3.594
# 1572     11 2012-10-26    1200729.45             0        74.26       3.506
#
#              CPI  Unemployment
# 1430  214.424881         7.368
# 1431  214.574792         7.368
# 1432  214.619887         7.368
# 1433  214.647513         7.368
# 1434  214.675139         7.368
# ...          ...           ...
# 1568  226.518093         6.334
# 1569  226.721036         6.034
# 1570  226.923979         6.034
# 1571  226.968844         6.034
# 1572  226.987364         6.034
#
# [143 rows x 8 columns]

# %%
df.set_index('Date', inplace=True)
df
# Out:
#             Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# Date
# 2010-02-05     11    1528008.64             0        46.04       2.572
# 2010-02-12     11    1574684.08             1        48.01       2.548
# 2010-02-19     11    1503298.70             0        48.30       2.514
# 2010-02-26     11    1336404.65             0        52.79       2.561
# 2010-03-05     11    1426622.65             0        53.96       2.625
# ...           ...           ...           ...          ...         ...
# 2012-09-28     11    1227430.73             0        77.67       3.666
# 2012-10-05     11    1422794.26             0        73.37       3.617
# 2012-10-12     11    1311965.09             0        69.94       3.601
# 2012-10-19     11    1232073.18             0        73.77       3.594
# 2012-10-26     11    1200729.45             0        74.26       3.506
#
#                    CPI  Unemployment
# Date
# 2010-02-05  214.424881         7.368
# 2010-02-12  214.574792         7.368
# 2010-02-19  214.619887         7.368
# 2010-02-26  214.647513         7.368
# 2010-03-05  214.675139         7.368
# ...                ...           ...
# 2012-09-28  226.518093         6.334
# 2012-10-05  226.721036         6.034
# 2012-10-12  226.923979         6.034
# 2012-10-19  226.968844         6.034
# 2012-10-26  226.987364         6.034
#
# [143 rows x 7 columns]

# %% [markdown]
# # Weekly_Sales

# %% [markdown]
# Dickey - Fuller aumentada

# %%
from statsmodels.tsa.stattools import adfuller

nivel_de_significancia = 0.05

# Realizar la prueba de Dickey-Fuller en los la tendencia
adf_test = adfuller(df['Weekly_Sales'].dropna()) # Realiza la prueba ADF


# Interpretación de la prueba ADF
print('Estadístico ADF:', adf_test[0])
print('p-value:', adf_test[1])

if adf_test[1] <= nivel_de_significancia:
    print("La tendencia es estacionaria (rechazamos la hipótesis nula).")
else:
    print("La tendencia no es estacionaria (aceptamos la hipótesis nula).")
# Out:
# Estadístico ADF: -3.762354325767339
# p-value: 0.003316836737490261
# La tendencia es estacionaria (rechazamos la hipótesis nula).

# %% [markdown]
# Regresión polinomial

# %%
from numpy.polynomial.polynomial import Polynomial
import matplotlib.pyplot as plt

# Paso 1: Convertir fechas a números
df['Date'] = pd.to_datetime(df.index).map(pd.Timestamp.timestamp)

# Paso 2: Definir las variables independientes (X) y la variable dependiente (y)
X = df['Date']
y = df['Weekly_Sales']

# Paso 3: Ajustar un modelo polinómico
grado = 3
modelo = Polynomial.fit(X, y, deg = grado)
df['Poly_Trend'] = modelo(X)
df['Poly_Resid'] = y - df['Poly_Trend']

# Graficar polinomial
# abre una nueva ventana gráfica
plt.figure(
    figsize=(12, 6) # tamaño (horizontal, vertical)
    )

# qué se va a graficar:
plt.plot(
    y,
    label='Ventas semanales', # etiqueta que aparecerá en la leyenda
    color='green'
    )

plt.plot(df['Poly_Trend'], label=f'Tendencia Polinómica (Grado {grado})', color='purple')
plt.title('Tendencia No Lineal de Ventas Semanales de Walmart') # Título
plt.xlabel('Fecha')                                           # nombre del eje x
plt.ylabel('Ventas semanales ($)')                            # nombre del eje y
plt.legend()                                                  # agrega la leyenda
plt.grid()                                                    # agrega una cuadrícula
plt.gca().spines['top'].set_visible(False)                    # elimina los bordes superiores
plt.gca().spines['right'].set_visible(False)                  # elimina los bordes derechos
plt.show()




# Graficar los residuales del polinomio
plt.figure(figsize=(12, 6)) # abre una nueva ventana gráfica
plt.plot(df['Poly_Resid'], label='Residuales', color='blue')
plt.axhline(0, color='red', label='Regresion',linestyle='--', linewidth=1)  # Línea horizontal en el valor cero
plt.title('Residuales de la regresion polinomial de Ventas de Walmart')
plt.xlabel('Fecha')
plt.ylabel('Desviacion de la regresion polinomial de Ventas ($)')
plt.legend()
plt.grid()
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.show()

# %% [markdown]
# Series de Fourier

# %%
def Transformada_de_Fourier(serie, terminos, un_grafico):
  '''La función acepta los argumentos "serie", la cual debe de ser un array
  en numpy y en pandas de la forma df["my_variable"].values. Por otra parte,
  el parámetro "terminos" es un número natural que indica la cantidad de
  términos que desarrolla la serie. Entre mayor sea el número de términos,
  la serie será más precisa, pero más difícil de interpretar.

  La función tiene como salida una lista con los componentes sinosoidales de serie.
  El último elemento de la lista, es la suma de todos los componentes'''

  import numpy as np
  import matplotlib.pyplot as plt
  import pandas as pd
  from scipy.fftpack import fft, ifft

  # Supongamos que tienes una serie en df['AAPL_Close']
  # Reemplaza esta línea con tu DataFrame y serie específicos
  n = len(serie)

  # Calcular la transformada de Fourier
  transformada_fourier = fft(serie)

  # Obtener las frecuencias
  frecuencias = np.fft.fftfreq(n)

  # Crear un DataFrame para almacenar la frecuencia y su magnitud
  componentes = pd.DataFrame({
      'frecuencia': frecuencias,
      'magnitud': np.abs(transformada_fourier),
      'longitud_de_onda': 1 / frecuencias
  })

  # Ordenar el dataframe de mayor a menor en términos de magnitud

  componentes = componentes.sort_values(by='magnitud', ascending=False)

  # Seleccionar las frecuencias con mayor magnitud (excluyendo la frecuencia cero)
  top_frecuencias = componentes.loc[componentes['frecuencia'] > 0].nlargest(terminos, 'magnitud')
  top_frecuencias.reset_index(drop=True, inplace=True)
  print("Frecuencias principales:\n", top_frecuencias)

  # Crear el índice de tiempo para la serie
  t = np.arange(n)

  # Graficar cada componente de frecuencia junto con la serie original
  plt.figure(figsize=(12, 4))

  componente_temporal_sumado = np.zeros_like(serie)
  componentes_temporales = []

  n=0
  for i, row in top_frecuencias.iterrows():
      n+=1
      # Copiar la transformada de Fourier y mantener solo la frecuencia actual
      fourier_component = np.zeros_like(transformada_fourier)
      idx = np.where(frecuencias == row['frecuencia'])[0][0]  # índice de la frecuencia en la FFT
      fourier_component[idx] = transformada_fourier[idx]  # mantener solo la frecuencia positiva
      fourier_component[-idx] = transformada_fourier[-idx]  # mantener la frecuencia negativa correspondiente
      if n == (terminos+1):
        break

      # Reconstruir la señal en el tiempo
      componente_temporal = ifft(fourier_component).real
      componentes_temporales.append(componente_temporal)
      componente_temporal_sumado += componente_temporal

      # Graficar la componente
      plt.plot(
          componente_temporal,
          label=f'Longitud de onda {1 / row["frecuencia"]:.0f}',
          alpha=1,
          linewidth = 0.5,
          )
      plt.title('Componentes de Fourier de la Serie')
      plt.xlabel('Tiempo')
      plt.ylabel('Valor')
      plt.legend()
      plt.grid()

  componentes_temporales.append(componente_temporal_sumado)
  plt.plot(serie, label='Serie Original', color='black', alpha=0.5)
  if not un_grafico:
    plt.figure(figsize=(12, 4))
    plt.plot(serie, label='Serie Original', color='black', alpha=0.5)
  plt.plot(componente_temporal_sumado, label='Componente temporal sumada', color='red')
  plt.legend()
  plt.title('Suma de los Componentes de Fourier de la Serie')
  plt.xlabel('Tiempo')
  plt.ylabel('Valor')
  plt.grid()
  plt.show()

# %%
serie = df['Poly_Resid'].values
terminos = 5
un_grafico = False

cts = Transformada_de_Fourier(serie, terminos, un_grafico)

# cts: componente temporal sumado
# Out:
# /tmp/ipython-input-3391697079.py:30: RuntimeWarning: divide by zero encountered in divide
#   'longitud_de_onda': 1 / frecuencias
# Frecuencias principales:
#     frecuencia      magnitud  longitud_de_onda
# 0    0.111888  4.656210e+06          8.937500
# 1    0.020979  4.303183e+06         47.666667
# 2    0.076923  4.277125e+06         13.000000
# 3    0.055944  4.257221e+06         17.875000
# 4    0.118881  3.638978e+06          8.411765

# %% [markdown]
# Series de fourier

# %%
df
# Out:
#             Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# Date
# 2010-02-05     11    1528008.64             0        46.04       2.572
# 2010-02-12     11    1574684.08             1        48.01       2.548
# 2010-02-19     11    1503298.70             0        48.30       2.514
# 2010-02-26     11    1336404.65             0        52.79       2.561
# 2010-03-05     11    1426622.65             0        53.96       2.625
# ...           ...           ...           ...          ...         ...
# 2012-09-28     11    1227430.73             0        77.67       3.666
# 2012-10-05     11    1422794.26             0        73.37       3.617
# 2012-10-12     11    1311965.09             0        69.94       3.601
# 2012-10-19     11    1232073.18             0        73.77       3.594
# 2012-10-26     11    1200729.45             0        74.26       3.506
#
#                    CPI  Unemployment          Date    Poly_Trend  \
# Date
# 2010-02-05  214.424881         7.368  1.265328e+09  1.419531e+06
# 2010-02-12  214.574792         7.368  1.265933e+09  1.412838e+06
# 2010-02-19  214.619887         7.368  1.266538e+09  1.406396e+06
# 2010-02-26  214.647513         7.368  1.267142e+09  1.400201e+06
# 2010-03-05  214.675139         7.368  1.267747e+09  1.394251e+06
# ...                ...           ...           ...           ...
# 2012-09-28  226.518093         6.334  1.348790e+09  1.306090e+06
# 2012-10-05  226.721036         6.034  1.349395e+09  1.299537e+06
# 2012-10-12  226.923979         6.034  1.350000e+09  1.292732e+06
# 2012-10-19  226.968844         6.034  1.350605e+09  1.285669e+06
# 2012-10-26  226.987364         6.034  1.351210e+09  1.278347e+06
#
#                Poly_Resid
# Date
# 2010-02-05  108477.284142
# 2010-02-12  161846.370285
# 2010-02-19   96903.186181
# 2010-02-26  -63796.462289
# 2010-03-05   32371.800760
# ...                   ...
# 2012-09-28  -78659.257416
# 2012-10-05  123256.844666
# 2012-10-12   19233.308328
# 2012-10-19  -53596.250549
# 2012-10-26  -77617.256081
#
# [143 rows x 10 columns]

# %% [markdown]
# Descomposición de la serie

# %%
# Descomponer la serie temporal
import statsmodels.api as sm

descomposicion = sm.tsa.seasonal_decompose(
    df['Weekly_Sales'],
    model='additive',
    period=9,
    extrapolate_trend=0,
    two_sided=False,
    )
fig = descomposicion.plot()
plt.show()

# %% [markdown]
# Dickey - Fuller aumentada

# %%
#Prueba de estacionariedad: Prueba de Dickey-Fuller aumentada (ADF)

#Hipótesis nula (H₀): La serie tiene una raíz unitaria (no es estacionaria).
#Hipótesis alternativa (H₁): La serie es estacionaria.

from statsmodels.tsa.stattools import adfuller

nivel_de_significancia = 0.05

# Realizar la prueba de Dickey-Fuller en los la tendencia
adf_test = adfuller(df['Poly_Resid'].dropna()) # Realiza la prueba ADF


# Interpretación de la prueba ADF
print('Estadístico ADF:', adf_test[0])
print('p-value:', adf_test[1])

if adf_test[1] <= nivel_de_significancia:
    print("La tendencia es estacionaria (rechazamos la hipótesis nula).")
else:
    print("La tendencia no es estacionaria (aceptamos la hipótesis nula).")
# Out:
# Estadístico ADF: -6.419010694757852
# p-value: 1.8110235278207158e-08
# La tendencia es estacionaria (rechazamos la hipótesis nula).

# %% [markdown]
# # Temperature

# %% [markdown]
# Dickey - Fuller aumentada

# %%
from statsmodels.tsa.stattools import adfuller

nivel_de_significancia = 0.05

# Realizar la prueba de Dickey-Fuller en los la tendencia
adf_test = adfuller(df["Temperature"].dropna()) # Realiza la prueba ADF


# Interpretación de la prueba ADF
print('Estadístico ADF:', adf_test[0])
print('p-value:', adf_test[1])

if adf_test[1] <= nivel_de_significancia:
    print("La tendencia es estacionaria (rechazamos la hipótesis nula).")
else:
    print("La tendencia no es estacionaria (aceptamos la hipótesis nula).")
# Out:
# Estadístico ADF: -4.858642626894152
# p-value: 4.1949240393894516e-05
# La tendencia es estacionaria (rechazamos la hipótesis nula).

# %% [markdown]
# Regresión polinomial

# %%
from numpy.polynomial.polynomial import Polynomial
import matplotlib.pyplot as plt

# Paso 1: Convertir fechas a números
df['Date'] = pd.to_datetime(df.index).map(pd.Timestamp.timestamp)

# Paso 2: Definir las variables independientes (X) y la variable dependiente (y)
X = df['Date']
y = df['Temperature']

# Paso 3: Ajustar un modelo polinómico
grado = 3
modelo = Polynomial.fit(X, y, deg = grado)
df['Poly_Trend'] = modelo(X)
df['Poly_Resid'] = y - df['Poly_Trend']

# Graficar polinomial
# abre una nueva ventana gráfica
plt.figure(
    figsize=(12, 6) # tamaño (horizontal, vertical)
    )

# qué se va a graficar:
plt.plot(
    y,
    label='Temperatura', # etiqueta que aparecerá en la leyenda
    color='green'
    )

plt.plot(df['Poly_Trend'], label=f'Tendencia Polinómica (Grado {grado})', color='purple')
plt.title('Tendencia No Lineal de Temperatura de Walmart') # Título
plt.xlabel('Fecha')                                           # nombre del eje x
plt.ylabel("Temperatura")                                      # nombre del eje y
plt.legend()                                                  # agrega la leyenda
plt.grid()                                                    # agrega una cuadrícula
plt.gca().spines['top'].set_visible(False)                    # elimina los bordes superiores
plt.gca().spines['right'].set_visible(False)                  # elimina los bordes derechos
plt.show()




# Graficar los residuales del polinomio
plt.figure(figsize=(12, 6)) # abre una nueva ventana gráfica
plt.plot(df['Poly_Resid'], label='Residuales', color='blue')
plt.axhline(0, color='red', label='Regresion',linestyle='--', linewidth=1)
plt.title('Residuales de la regresion polinomial de Temperatura de Walmart')
plt.xlabel('Fecha')
plt.ylabel('Desviacion de la regresion polinomial')
plt.legend()
plt.grid()
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.show()

# %% [markdown]
# Series de Fourier

# %%
def Transformada_de_Fourier(serie, terminos, un_grafico):
  '''La función acepta los argumentos "serie", la cual debe de ser un array
  en numpy y en pandas de la forma df["my_variable"].values. Por otra parte,
  el parámetro "terminos" es un número natural que indica la cantidad de
  términos que desarrolla la serie. Entre mayor sea el número de términos,
  la serie será más precisa, pero más difícil de interpretar.

  La función tiene como salida una lista con los componentes sinosoidales de serie.
  El último elemento de la lista, es la suma de todos los componentes'''

  import numpy as np
  import matplotlib.pyplot as plt
  import pandas as pd
  from scipy.fftpack import fft, ifft

  # Supongamos que tienes una serie en df['AAPL_Close']
  # Reemplaza esta línea con tu DataFrame y serie específicos
  n = len(serie)

  # Calcular la transformada de Fourier
  transformada_fourier = fft(serie)

  # Obtener las frecuencias
  frecuencias = np.fft.fftfreq(n)

  # Crear un DataFrame para almacenar la frecuencia y su magnitud
  componentes = pd.DataFrame({
      'frecuencia': frecuencias,
      'magnitud': np.abs(transformada_fourier),
      'longitud_de_onda': 1 / frecuencias
  })

  # Ordenar el dataframe de mayor a menor en términos de magnitud

  componentes = componentes.sort_values(by='magnitud', ascending=False)

  # Seleccionar las frecuencias con mayor magnitud (excluyendo la frecuencia cero)
  top_frecuencias = componentes.loc[componentes['frecuencia'] > 0].nlargest(terminos, 'magnitud')
  top_frecuencias.reset_index(drop=True, inplace=True)
  print("Frecuencias principales:\n", top_frecuencias)

  # Crear el índice de tiempo para la serie
  t = np.arange(n)

  # Graficar cada componente de frecuencia junto con la serie original
  plt.figure(figsize=(12, 4))

  componente_temporal_sumado = np.zeros_like(serie)
  componentes_temporales = []

  n=0
  for i, row in top_frecuencias.iterrows():
      n+=1
      # Copiar la transformada de Fourier y mantener solo la frecuencia actual
      fourier_component = np.zeros_like(transformada_fourier)
      idx = np.where(frecuencias == row['frecuencia'])[0][0]  # índice de la frecuencia en la FFT
      fourier_component[idx] = transformada_fourier[idx]  # mantener solo la frecuencia positiva
      fourier_component[-idx] = transformada_fourier[-idx]  # mantener la frecuencia negativa correspondiente
      if n == (terminos+1):
        break

      # Reconstruir la señal en el tiempo
      componente_temporal = ifft(fourier_component).real
      componentes_temporales.append(componente_temporal)
      componente_temporal_sumado += componente_temporal

      # Graficar la componente
      plt.plot(
          componente_temporal,
          label=f'Longitud de onda {1 / row["frecuencia"]:.0f}',
          alpha=1,
          linewidth = 0.5,
          )
      plt.title('Componentes de Fourier de la Serie')
      plt.xlabel('Tiempo')
      plt.ylabel('Valor')
      plt.legend()
      plt.grid()

  componentes_temporales.append(componente_temporal_sumado)
  plt.plot(serie, label='Serie Original', color='black', alpha=0.5)
  if not un_grafico:
    plt.figure(figsize=(12, 4))
    plt.plot(serie, label='Serie Original', color='black', alpha=0.5)
  plt.plot(componente_temporal_sumado, label='Componente temporal sumada', color='red')
  plt.legend()
  plt.title('Suma de los Componentes de Fourier de la Serie')
  plt.xlabel('Tiempo')
  plt.ylabel('Valor')
  plt.grid()
  plt.show()

# %%
serie = df['Poly_Resid'].values
terminos = 5
un_grafico = False

cts = Transformada_de_Fourier(serie, terminos, un_grafico)

# cts: componente temporal sumado
# Out:
# /tmp/ipython-input-3391697079.py:30: RuntimeWarning: divide by zero encountered in divide
#   'longitud_de_onda': 1 / frecuencias
# Frecuencias principales:
#     frecuencia     magnitud  longitud_de_onda
# 0    0.020979  1008.967919         47.666667
# 1    0.013986   522.978943         71.500000
# 2    0.041958   184.025672         23.833333
# 3    0.027972   128.429538         35.750000
# 4    0.055944    93.330572         17.875000

# %%
df
# Out:
#             Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# Date
# 2010-02-05     11    1528008.64             0        46.04       2.572
# 2010-02-12     11    1574684.08             1        48.01       2.548
# 2010-02-19     11    1503298.70             0        48.30       2.514
# 2010-02-26     11    1336404.65             0        52.79       2.561
# 2010-03-05     11    1426622.65             0        53.96       2.625
# ...           ...           ...           ...          ...         ...
# 2012-09-28     11    1227430.73             0        77.67       3.666
# 2012-10-05     11    1422794.26             0        73.37       3.617
# 2012-10-12     11    1311965.09             0        69.94       3.601
# 2012-10-19     11    1232073.18             0        73.77       3.594
# 2012-10-26     11    1200729.45             0        74.26       3.506
#
#                    CPI  Unemployment          Date  Poly_Trend  Poly_Resid
# Date
# 2010-02-05  214.424881         7.368  1.265328e+09   60.859587  -14.819587
# 2010-02-12  214.574792         7.368  1.265933e+09   61.588662  -13.578662
# 2010-02-19  214.619887         7.368  1.266538e+09   62.293519  -13.993519
# 2010-02-26  214.647513         7.368  1.267142e+09   62.974509  -10.184509
# 2010-03-05  214.675139         7.368  1.267747e+09   63.631979   -9.671979
# ...                ...           ...           ...         ...         ...
# 2012-09-28  226.518093         6.334  1.348790e+09   81.766529   -4.096529
# 2012-10-05  226.721036         6.034  1.349395e+09   82.445181   -9.075181
# 2012-10-12  226.923979         6.034  1.350000e+09   83.147666  -13.207666
# 2012-10-19  226.968844         6.034  1.350605e+09   83.874333  -10.104333
# 2012-10-26  226.987364         6.034  1.351210e+09   84.625530  -10.365530
#
# [143 rows x 10 columns]

# %% [markdown]
# Descomposición de la serie

# %%
# Descomponer la serie temporal
import statsmodels.api as sm

descomposicion = sm.tsa.seasonal_decompose(
    df['Temperature'],
    model='additive',
    period=48,
    extrapolate_trend=0,
    two_sided=False,
    )
fig = descomposicion.plot()
plt.show()

# %% [markdown]
# Dickey - Fuller aumentada

# %%
#Prueba de estacionariedad: Prueba de Dickey-Fuller aumentada (ADF)

#Hipótesis nula (H₀): La serie tiene una raíz unitaria (no es estacionaria).
#Hipótesis alternativa (H₁): La serie es estacionaria.

from statsmodels.tsa.stattools import adfuller

nivel_de_significancia = 0.05

# Realizar la prueba de Dickey-Fuller en los la tendencia
adf_test = adfuller(df['Poly_Resid'].dropna()) # Realiza la prueba ADF


# Interpretación de la prueba ADF
print('Estadístico ADF:', adf_test[0])
print('p-value:', adf_test[1])

if adf_test[1] <= nivel_de_significancia:
    print("La tendencia es estacionaria (rechazamos la hipótesis nula).")
else:
    print("La tendencia no es estacionaria (aceptamos la hipótesis nula).")
# Out:
# Estadístico ADF: -4.763525042274461
# p-value: 6.3831501002497e-05
# La tendencia es estacionaria (rechazamos la hipótesis nula).

# %% [markdown]
# # Fuel_price

# %% [markdown]
# Dickey

# %%
from statsmodels.tsa.stattools import adfuller

nivel_de_significancia = 0.05

# Realizar la prueba de Dickey-Fuller en los la tendencia
adf_test = adfuller(df["Fuel_Price"].dropna()) # Realiza la prueba ADF


# Interpretación de la prueba ADF
print('Estadístico ADF:', adf_test[0])
print('p-value:', adf_test[1])

if adf_test[1] <= nivel_de_significancia:
    print("La tendencia es estacionaria (rechazamos la hipótesis nula).")
else:
    print("La tendencia no es estacionaria (aceptamos la hipótesis nula).")
# Out:
# Estadístico ADF: -1.908076434238512
# p-value: 0.32827129211186756
# La tendencia no es estacionaria (aceptamos la hipótesis nula).

# %% [markdown]
# Regresion

# %%
from numpy.polynomial.polynomial import Polynomial
import matplotlib.pyplot as plt

# Paso 1: Convertir fechas a números
df['Date'] = pd.to_datetime(df.index).map(pd.Timestamp.timestamp)

# Paso 2: Definir las variables independientes (X) y la variable dependiente (y)
X = df['Date']
y = df['Fuel_Price']

# Paso 3: Ajustar un modelo polinómico
grado = 4
modelo = Polynomial.fit(X, y, deg = grado)
df['Poly_Trend'] = modelo(X)
df['Poly_Resid'] = y - df['Poly_Trend']

# Graficar polinomial
# abre una nueva ventana gráfica
plt.figure(
    figsize=(12, 6) # tamaño (horizontal, vertical)
    )

# qué se va a graficar:
plt.plot(
    y,
    label='Precio del combustible', # etiqueta que aparecerá en la leyenda
    color='green'
    )

plt.plot(df['Poly_Trend'], label=f'Tendencia Polinómica (Grado {grado})', color='purple')
plt.title('Tendencia No Lineal de Precio del Combustible de Walmart') # Título
plt.xlabel('Fecha')                                           # nombre del eje x
plt.ylabel('Precio del combustible ($)')                            # nombre del eje y
plt.legend()                                                  # agrega la leyenda
plt.grid()                                                    # agrega una cuadrícula
plt.gca().spines['top'].set_visible(False)                    # elimina los bordes superiores
plt.gca().spines['right'].set_visible(False)                  # elimina los bordes derechos
plt.show()




# Graficar los residuales del polinomio
plt.figure(figsize=(12, 6)) # abre una nueva ventana gráfica
plt.plot(df['Poly_Resid'], label='Residuales', color='blue')
plt.axhline(0, color='red', label='Regresion',linestyle='--', linewidth=1)  # Línea horizontal en el valor cero
plt.title('Residuales de la regresion polinomial de Precio del Combustible de Walmart')
plt.xlabel('Fecha')
plt.ylabel('Desviacion de la regresion polinomial ($)')
plt.legend()
plt.grid()
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.show()

# %%
def Transformada_de_Fourier(serie, terminos, un_grafico):
  '''La función acepta los argumentos "serie", la cual debe de ser un array
  en numpy y en pandas de la forma df["my_variable"].values. Por otra parte,
  el parámetro "terminos" es un número natural que indica la cantidad de
  términos que desarrolla la serie. Entre mayor sea el número de términos,
  la serie será más precisa, pero más difícil de interpretar.

  La función tiene como salida una lista con los componentes sinosoidales de serie.
  El último elemento de la lista, es la suma de todos los componentes'''

  import numpy as np
  import matplotlib.pyplot as plt
  import pandas as pd
  from scipy.fftpack import fft, ifft

  # Supongamos que tienes una serie en df['AAPL_Close']
  # Reemplaza esta línea con tu DataFrame y serie específicos
  n = len(serie)

  # Calcular la transformada de Fourier
  transformada_fourier = fft(serie)

  # Obtener las frecuencias
  frecuencias = np.fft.fftfreq(n)

  # Crear un DataFrame para almacenar la frecuencia y su magnitud
  componentes = pd.DataFrame({
      'frecuencia': frecuencias,
      'magnitud': np.abs(transformada_fourier),
      'longitud_de_onda': 1 / frecuencias
  })

  # Ordenar el dataframe de mayor a menor en términos de magnitud

  componentes = componentes.sort_values(by='magnitud', ascending=False)

  # Seleccionar las frecuencias con mayor magnitud (excluyendo la frecuencia cero)
  top_frecuencias = componentes.loc[componentes['frecuencia'] > 0].nlargest(terminos, 'magnitud')
  top_frecuencias.reset_index(drop=True, inplace=True)
  print("Frecuencias principales:\n", top_frecuencias)

  # Crear el índice de tiempo para la serie
  t = np.arange(n)

  # Graficar cada componente de frecuencia junto con la serie original
  plt.figure(figsize=(12, 4))

  componente_temporal_sumado = np.zeros_like(serie)
  componentes_temporales = []

  n=0
  for i, row in top_frecuencias.iterrows():
      n+=1
      # Copiar la transformada de Fourier y mantener solo la frecuencia actual
      fourier_component = np.zeros_like(transformada_fourier)
      idx = np.where(frecuencias == row['frecuencia'])[0][0]  # índice de la frecuencia en la FFT
      fourier_component[idx] = transformada_fourier[idx]  # mantener solo la frecuencia positiva
      fourier_component[-idx] = transformada_fourier[-idx]  # mantener la frecuencia negativa correspondiente
      if n == (terminos+1):
        break

      # Reconstruir la señal en el tiempo
      componente_temporal = ifft(fourier_component).real
      componentes_temporales.append(componente_temporal)
      componente_temporal_sumado += componente_temporal

      # Graficar la componente
      plt.plot(
          componente_temporal,
          label=f'Longitud de onda {1 / row["frecuencia"]:.0f}',
          alpha=1,
          linewidth = 0.5,
          )
      plt.title('Componentes de Fourier de la Serie')
      plt.xlabel('Tiempo')
      plt.ylabel('Valor')
      plt.legend()
      plt.grid()

  componentes_temporales.append(componente_temporal_sumado)
  plt.plot(serie, label='Serie Original', color='black', alpha=0.5)
  if not un_grafico:
    plt.figure(figsize=(12, 4))
    plt.plot(serie, label='Serie Original', color='black', alpha=0.5)
  plt.plot(componente_temporal_sumado, label='Componente temporal sumada', color='red')
  plt.legend()
  plt.title('Suma de los Componentes de Fourier de la Serie')
  plt.xlabel('Tiempo')
  plt.ylabel('Valor')
  plt.grid()
  plt.show()

# %%
serie = df['Poly_Resid'].values
terminos = 5
un_grafico = False

cts = Transformada_de_Fourier(serie, terminos, un_grafico)

# cts: componente temporal sumado
# Out:
# /tmp/ipython-input-3391697079.py:30: RuntimeWarning: divide by zero encountered in divide
#   'longitud_de_onda': 1 / frecuencias
# Frecuencias principales:
#     frecuencia   magnitud  longitud_de_onda
# 0    0.020979  15.661871         47.666667
# 1    0.041958   8.544744         23.833333
# 2    0.013986   8.077845         71.500000
# 3    0.055944   5.195303         17.875000
# 4    0.027972   3.642410         35.750000

# %%
df
# Out:
#             Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# Date
# 2010-02-05     11    1528008.64             0        46.04       2.572
# 2010-02-12     11    1574684.08             1        48.01       2.548
# 2010-02-19     11    1503298.70             0        48.30       2.514
# 2010-02-26     11    1336404.65             0        52.79       2.561
# 2010-03-05     11    1426622.65             0        53.96       2.625
# ...           ...           ...           ...          ...         ...
# 2012-09-28     11    1227430.73             0        77.67       3.666
# 2012-10-05     11    1422794.26             0        73.37       3.617
# 2012-10-12     11    1311965.09             0        69.94       3.601
# 2012-10-19     11    1232073.18             0        73.77       3.594
# 2012-10-26     11    1200729.45             0        74.26       3.506
#
#                    CPI  Unemployment          Date  Poly_Trend  Poly_Resid
# Date
# 2010-02-05  214.424881         7.368  1.265328e+09    2.808627   -0.236627
# 2010-02-12  214.574792         7.368  1.265933e+09    2.776096   -0.228096
# 2010-02-19  214.619887         7.368  1.266538e+09    2.746408   -0.232408
# 2010-02-26  214.647513         7.368  1.267142e+09    2.719470   -0.158470
# 2010-03-05  214.675139         7.368  1.267747e+09    2.695189   -0.070189
# ...                ...           ...           ...         ...         ...
# 2012-09-28  226.518093         6.334  1.348790e+09    3.630831    0.035169
# 2012-10-05  226.721036         6.034  1.349395e+09    3.655105   -0.038105
# 2012-10-12  226.923979         6.034  1.350000e+09    3.681416   -0.080416
# 2012-10-19  226.968844         6.034  1.350605e+09    3.709847   -0.115847
# 2012-10-26  226.987364         6.034  1.351210e+09    3.740481   -0.234481
#
# [143 rows x 10 columns]

# %%
# Descomponer la serie temporal
import statsmodels.api as sm

descomposicion = sm.tsa.seasonal_decompose(
    df['Fuel_Price'],
    model='additive',
    period=48,
    extrapolate_trend=0,
    two_sided=False,
    )  #
fig = descomposicion.plot()
plt.show()

# %% [markdown]
# Dickey

# %%
#Prueba de estacionariedad: Prueba de Dickey-Fuller aumentada (ADF)

#Hipótesis nula (H₀): La serie tiene una raíz unitaria (no es estacionaria).
#Hipótesis alternativa (H₁): La serie es estacionaria.

from statsmodels.tsa.stattools import adfuller

nivel_de_significancia = 0.05

# Realizar la prueba de Dickey-Fuller en los la tendencia
adf_test = adfuller(df['Poly_Resid'].dropna()) # Realiza la prueba ADF


# Interpretación de la prueba ADF
print('Estadístico ADF:', adf_test[0])
print('p-value:', adf_test[1])

if adf_test[1] <= nivel_de_significancia:
    print("La tendencia es estacionaria (rechazamos la hipótesis nula).")
else:
    print("La tendencia no es estacionaria (aceptamos la hipótesis nula).")
# Out:
# Estadístico ADF: -3.550871895500462
# p-value: 0.006772770734548918
# La tendencia es estacionaria (rechazamos la hipótesis nula).

# %% [markdown]
# # CPI

# %%
from statsmodels.tsa.stattools import adfuller

nivel_de_significancia = 0.05

# Realizar la prueba de Dickey-Fuller en los la tendencia
adf_test = adfuller(df["CPI"].dropna()) # Realiza la prueba ADF


# Interpretación de la prueba ADF
print('Estadístico ADF:', adf_test[0])
print('p-value:', adf_test[1])

if adf_test[1] <= nivel_de_significancia:
    print("La tendencia es estacionaria (rechazamos la hipótesis nula).")
else:
    print("La tendencia no es estacionaria (aceptamos la hipótesis nula).")
# Out:
# Estadístico ADF: 0.23595824782902422
# p-value: 0.9742077851144497
# La tendencia no es estacionaria (aceptamos la hipótesis nula).

# %% [markdown]
# regresion polinomial

# %%
from numpy.polynomial.polynomial import Polynomial
import matplotlib.pyplot as plt

# Paso 1: Convertir fechas a números
df['Date'] = pd.to_datetime(df.index).map(pd.Timestamp.timestamp)

# Paso 2: Definir las variables independientes (X) y la variable dependiente (y)
X = df['Date']
y = df['CPI']

# Paso 3: Ajustar un modelo polinómico
grado = 4
modelo = Polynomial.fit(X, y, deg = grado)
df['Poly_Trend'] = modelo(X)
df['Poly_Resid'] = y - df['Poly_Trend']

# Graficar polinomial
# abre una nueva ventana gráfica
plt.figure(
    figsize=(12, 6) # tamaño (horizontal, vertical)
    )

# qué se va a graficar:
plt.plot(
    y,
    label='CPI', # etiqueta que aparecerá en la leyenda
    color='green'
    )

plt.plot(df['Poly_Trend'], label=f'Tendencia Polinómica (Grado {grado})', color='purple')
plt.title('Tendencia No Lineal de CPI de Walmart') # Título
plt.xlabel('Fecha')                                           # nombre del eje x
plt.ylabel('CPI ($)')                            # nombre del eje y
plt.legend()                                                  # agrega la leyenda
plt.grid()                                                    # agrega una cuadrícula
plt.gca().spines['top'].set_visible(False)                    # elimina los bordes superiores
plt.gca().spines['right'].set_visible(False)                  # elimina los bordes derechos
plt.show()




# Graficar los residuales del polinomio
plt.figure(figsize=(12, 6)) # abre una nueva ventana gráfica
plt.plot(df['Poly_Resid'], label='Residuales', color='blue')
plt.axhline(0, color='red', label='Regresion',linestyle='--', linewidth=1)  # Línea horizontal en el valor cero
plt.title('Residuales de la regresion polinomial de CPI de Walmart')
plt.xlabel('Fecha')
plt.ylabel('Desviacion de la regresion polinomial ($)')
plt.legend()
plt.grid()
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.show()

# %% [markdown]
# series de fourier

# %%
def Transformada_de_Fourier(serie, terminos, un_grafico):
  '''La función acepta los argumentos "serie", la cual debe de ser un array
  en numpy y en pandas de la forma df["my_variable"].values. Por otra parte,
  el parámetro "terminos" es un número natural que indica la cantidad de
  términos que desarrolla la serie. Entre mayor sea el número de términos,
  la serie será más precisa, pero más difícil de interpretar.

  La función tiene como salida una lista con los componentes sinosoidales de serie.
  El último elemento de la lista, es la suma de todos los componentes'''

  import numpy as np
  import matplotlib.pyplot as plt
  import pandas as pd
  from scipy.fftpack import fft, ifft

  # Supongamos que tienes una serie en df['AAPL_Close']
  # Reemplaza esta línea con tu DataFrame y serie específicos
  n = len(serie)

  # Calcular la transformada de Fourier
  transformada_fourier = fft(serie)

  # Obtener las frecuencias
  frecuencias = np.fft.fftfreq(n)

  # Crear un DataFrame para almacenar la frecuencia y su magnitud
  componentes = pd.DataFrame({
      'frecuencia': frecuencias,
      'magnitud': np.abs(transformada_fourier),
      'longitud_de_onda': 1 / frecuencias
  })

  # Ordenar el dataframe de mayor a menor en términos de magnitud

  componentes = componentes.sort_values(by='magnitud', ascending=False)

  # Seleccionar las frecuencias con mayor magnitud (excluyendo la frecuencia cero)
  top_frecuencias = componentes.loc[componentes['frecuencia'] > 0].nlargest(terminos, 'magnitud')
  top_frecuencias.reset_index(drop=True, inplace=True)
  print("Frecuencias principales:\n", top_frecuencias)

  # Crear el índice de tiempo para la serie
  t = np.arange(n)

  # Graficar cada componente de frecuencia junto con la serie original
  plt.figure(figsize=(12, 4))

  componente_temporal_sumado = np.zeros_like(serie)
  componentes_temporales = []

  n=0
  for i, row in top_frecuencias.iterrows():
      n+=1
      # Copiar la transformada de Fourier y mantener solo la frecuencia actual
      fourier_component = np.zeros_like(transformada_fourier)
      idx = np.where(frecuencias == row['frecuencia'])[0][0]  # índice de la frecuencia en la FFT
      fourier_component[idx] = transformada_fourier[idx]  # mantener solo la frecuencia positiva
      fourier_component[-idx] = transformada_fourier[-idx]  # mantener la frecuencia negativa correspondiente
      if n == (terminos+1):
        break

      # Reconstruir la señal en el tiempo
      componente_temporal = ifft(fourier_component).real
      componentes_temporales.append(componente_temporal)
      componente_temporal_sumado += componente_temporal

      # Graficar la componente
      plt.plot(
          componente_temporal,
          label=f'Longitud de onda {1 / row["frecuencia"]:.0f}',
          alpha=1,
          linewidth = 0.5,
          )
      plt.title('Componentes de Fourier de la Serie')
      plt.xlabel('Tiempo')
      plt.ylabel('Valor')
      plt.legend()
      plt.grid()

  componentes_temporales.append(componente_temporal_sumado)
  plt.plot(serie, label='Serie Original', color='black', alpha=0.5)
  if not un_grafico:
    plt.figure(figsize=(12, 4))
    plt.plot(serie, label='Serie Original', color='black', alpha=0.5)
  plt.plot(componente_temporal_sumado, label='Componente temporal sumada', color='red')
  plt.legend()
  plt.title('Suma de los Componentes de Fourier de la Serie')
  plt.xlabel('Tiempo')
  plt.ylabel('Valor')
  plt.grid()
  plt.show()

# %%
serie = df['Poly_Resid'].values
terminos = 5
un_grafico = False

cts = Transformada_de_Fourier(serie, terminos, un_grafico)

# cts: componente temporal sumado
# Out:
# /tmp/ipython-input-3391697079.py:30: RuntimeWarning: divide by zero encountered in divide
#   'longitud_de_onda': 1 / frecuencias
# Frecuencias principales:
#     frecuencia   magnitud  longitud_de_onda
# 0    0.027972  34.470501         35.750000
# 1    0.020979  30.220580         47.666667
# 2    0.034965  22.333228         28.600000
# 3    0.048951  12.381941         20.428571
# 4    0.041958  10.376322         23.833333

# %%
df
# Out:
#             Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# Date
# 2010-02-05     11    1528008.64             0        46.04       2.572
# 2010-02-12     11    1574684.08             1        48.01       2.548
# 2010-02-19     11    1503298.70             0        48.30       2.514
# 2010-02-26     11    1336404.65             0        52.79       2.561
# 2010-03-05     11    1426622.65             0        53.96       2.625
# ...           ...           ...           ...          ...         ...
# 2012-09-28     11    1227430.73             0        77.67       3.666
# 2012-10-05     11    1422794.26             0        73.37       3.617
# 2012-10-12     11    1311965.09             0        69.94       3.601
# 2012-10-19     11    1232073.18             0        73.77       3.594
# 2012-10-26     11    1200729.45             0        74.26       3.506
#
#                    CPI  Unemployment          Date  Poly_Trend  Poly_Resid
# Date
# 2010-02-05  214.424881         7.368  1.265328e+09  214.509580   -0.084699
# 2010-02-12  214.574792         7.368  1.265933e+09  214.473304    0.101487
# 2010-02-19  214.619887         7.368  1.266538e+09  214.439681    0.180206
# 2010-02-26  214.647513         7.368  1.267142e+09  214.408730    0.238783
# 2010-03-05  214.675139         7.368  1.267747e+09  214.380474    0.294664
# ...                ...           ...           ...         ...         ...
# 2012-09-28  226.518093         6.334  1.348790e+09  226.341884    0.176208
# 2012-10-05  226.721036         6.034  1.349395e+09  226.355884    0.365152
# 2012-10-12  226.923979         6.034  1.350000e+09  226.364009    0.559969
# 2012-10-19  226.968844         6.034  1.350605e+09  226.366114    0.602730
# 2012-10-26  226.987364         6.034  1.351210e+09  226.362050    0.625314
#
# [143 rows x 10 columns]

# %%
# Descomponer la serie temporal
import statsmodels.api as sm

descomposicion = sm.tsa.seasonal_decompose(
    df['CPI'],
    model='additive',
    period=36,
    extrapolate_trend=0,
    two_sided=False,
    )
fig = descomposicion.plot()
plt.show()

# %% [markdown]
# Dickey

# %%
#Prueba de estacionariedad: Prueba de Dickey-Fuller aumentada (ADF)

#Hipótesis nula (H₀): La serie tiene una raíz unitaria (no es estacionaria).
#Hipótesis alternativa (H₁): La serie es estacionaria.

from statsmodels.tsa.stattools import adfuller

nivel_de_significancia = 0.05

# Realizar la prueba de Dickey-Fuller en los la tendencia
adf_test = adfuller(df['Poly_Resid'].dropna()) # Realiza la prueba ADF


# Interpretación de la prueba ADF
print('Estadístico ADF:', adf_test[0])
print('p-value:', adf_test[1])

if adf_test[1] <= nivel_de_significancia:
    print("La tendencia es estacionaria (rechazamos la hipótesis nula).")
else:
    print("La tendencia no es estacionaria (aceptamos la hipótesis nula).")
# Out:
# Estadístico ADF: -4.850356625402095
# p-value: 4.352384586339034e-05
# La tendencia es estacionaria (rechazamos la hipótesis nula).

# %% [markdown]
# # Unemployment

# %% [markdown]
# Dickey - Fuller aumentada

# %%
from statsmodels.tsa.stattools import adfuller

nivel_de_significancia = 0.05

# Realizar la prueba de Dickey-Fuller en los la tendencia
adf_test = adfuller(df["Unemployment"].dropna()) # Realiza la prueba ADF


# Interpretación de la prueba ADF
print('Estadístico ADF:', adf_test[0])
print('p-value:', adf_test[1])

if adf_test[1] <= nivel_de_significancia:
    print("La tendencia es estacionaria (rechazamos la hipótesis nula).")
else:
    print("La tendencia no es estacionaria (aceptamos la hipótesis nula).")
# Out:
# Estadístico ADF: 0.16736916276133365
# p-value: 0.9703708860384199
# La tendencia no es estacionaria (aceptamos la hipótesis nula).

# %% [markdown]
# Regresión polinomial

# %%
from numpy.polynomial.polynomial import Polynomial
import matplotlib.pyplot as plt

# Paso 1: Convertir fechas a números
df['Date'] = pd.to_datetime(df.index).map(pd.Timestamp.timestamp)

# Paso 2: Definir las variables independientes (X) y la variable dependiente (y)
X = df['Date']
y = df['Unemployment']

# Paso 3: Ajustar un modelo polinómico
grado = 4
modelo = Polynomial.fit(X, y, deg = grado)
df['Poly_Trend'] = modelo(X)
df['Poly_Resid'] = y - df['Poly_Trend']

# Graficar polinomial
# abre una nueva ventana gráfica
plt.figure(
    figsize=(12, 6) # tamaño (horizontal, vertical)
    )

# qué se va a graficar:
plt.plot(
    y,
    label='Tasa de desempleo', # etiqueta que aparecerá en la leyenda
    color='green'
    )

plt.plot(df['Poly_Trend'], label=f'Tendencia Polinómica (Grado {grado})', color='purple')
plt.title('Tendencia No Lineal de Tasa de Desempleo de Walmart') # Título
plt.xlabel('Fecha')                                           # nombre del eje x
plt.ylabel('Tasa de desempleo')                            # nombre del eje y
plt.legend()                                                  # agrega la leyenda
plt.grid()                                                    # agrega una cuadrícula
plt.gca().spines['top'].set_visible(False)                    # elimina los bordes superiores
plt.gca().spines['right'].set_visible(False)                  # elimina los bordes derechos
plt.show()




# Graficar los residuales del polinomio
plt.figure(figsize=(12, 6)) # abre una nueva ventana gráfica
plt.plot(df['Poly_Resid'], label='Residuales', color='blue')
plt.axhline(0, color='red', label='Regresion',linestyle='--', linewidth=1)  # Línea horizontal en el valor cero
plt.title('Residuales de la regresion polinomial de Tasa de Desempleo de Walmart')
plt.xlabel('Fecha')
plt.ylabel('Desviacion de la regresion polinomial')
plt.legend()
plt.grid()
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.show()

# %% [markdown]
# Series de Fourier

# %%
def Transformada_de_Fourier(serie, terminos, un_grafico):
  '''La función acepta los argumentos "serie", la cual debe de ser un array
  en numpy y en pandas de la forma df["my_variable"].values. Por otra parte,
  el parámetro "terminos" es un número natural que indica la cantidad de
  términos que desarrolla la serie. Entre mayor sea el número de términos,
  la serie será más precisa, pero más difícil de interpretar.

  La función tiene como salida una lista con los componentes sinosoidales de serie.
  El último elemento de la lista, es la suma de todos los componentes'''

  import numpy as np
  import matplotlib.pyplot as plt
  import pandas as pd
  from scipy.fftpack import fft, ifft

  # Supongamos que tienes una serie en df['AAPL_Close']
  # Reemplaza esta línea con tu DataFrame y serie específicos
  n = len(serie)

  # Calcular la transformada de Fourier
  transformada_fourier = fft(serie)

  # Obtener las frecuencias
  frecuencias = np.fft.fftfreq(n)

  # Crear un DataFrame para almacenar la frecuencia y su magnitud
  componentes = pd.DataFrame({
      'frecuencia': frecuencias,
      'magnitud': np.abs(transformada_fourier),
      'longitud_de_onda': 1 / frecuencias
  })

  # Ordenar el dataframe de mayor a menor en términos de magnitud

  componentes = componentes.sort_values(by='magnitud', ascending=False)

  # Seleccionar las frecuencias con mayor magnitud (excluyendo la frecuencia cero)
  top_frecuencias = componentes.loc[componentes['frecuencia'] > 0].nlargest(terminos, 'magnitud')
  top_frecuencias.reset_index(drop=True, inplace=True)
  print("Frecuencias principales:\n", top_frecuencias)

  # Crear el índice de tiempo para la serie
  t = np.arange(n)

  # Graficar cada componente de frecuencia junto con la serie original
  plt.figure(figsize=(12, 4))

  componente_temporal_sumado = np.zeros_like(serie)
  componentes_temporales = []

  n=0
  for i, row in top_frecuencias.iterrows():
      n+=1
      # Copiar la transformada de Fourier y mantener solo la frecuencia actual
      fourier_component = np.zeros_like(transformada_fourier)
      idx = np.where(frecuencias == row['frecuencia'])[0][0]  # índice de la frecuencia en la FFT
      fourier_component[idx] = transformada_fourier[idx]  # mantener solo la frecuencia positiva
      fourier_component[-idx] = transformada_fourier[-idx]  # mantener la frecuencia negativa correspondiente
      if n == (terminos+1):
        break

      # Reconstruir la señal en el tiempo
      componente_temporal = ifft(fourier_component).real
      componentes_temporales.append(componente_temporal)
      componente_temporal_sumado += componente_temporal

      # Graficar la componente
      plt.plot(
          componente_temporal,
          label=f'Longitud de onda {1 / row["frecuencia"]:.0f}',
          alpha=1,
          linewidth = 0.5,
          )
      plt.title('Componentes de Fourier de la Serie')
      plt.xlabel('Tiempo')
      plt.ylabel('Valor')
      plt.legend()
      plt.grid()

  componentes_temporales.append(componente_temporal_sumado)
  plt.plot(serie, label='Serie Original', color='black', alpha=0.5)
  if not un_grafico:
    plt.figure(figsize=(12, 4))
    plt.plot(serie, label='Serie Original', color='black', alpha=0.5)
  plt.plot(componente_temporal_sumado, label='Componente temporal sumada', color='red')
  plt.legend()
  plt.title('Suma de los Componentes de Fourier de la Serie')
  plt.xlabel('Tiempo')
  plt.ylabel('Valor')
  plt.grid()
  plt.show()

# %%
serie = df['Poly_Resid'].values
terminos = 5
un_grafico = False

cts = Transformada_de_Fourier(serie, terminos, un_grafico)

# cts: componente temporal sumado
# Out:
# /tmp/ipython-input-3391697079.py:30: RuntimeWarning: divide by zero encountered in divide
#   'longitud_de_onda': 1 / frecuencias
# Frecuencias principales:
#     frecuencia  magnitud  longitud_de_onda
# 0    0.020979  3.246665         47.666667
# 1    0.027972  3.187055         35.750000
# 2    0.076923  2.930790         13.000000
# 3    0.069930  2.682367         14.300000
# 4    0.083916  2.488907         11.916667

# %%
df
# Out:
#             Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# Date
# 2010-02-05     11    1528008.64             0        46.04       2.572
# 2010-02-12     11    1574684.08             1        48.01       2.548
# 2010-02-19     11    1503298.70             0        48.30       2.514
# 2010-02-26     11    1336404.65             0        52.79       2.561
# 2010-03-05     11    1426622.65             0        53.96       2.625
# ...           ...           ...           ...          ...         ...
# 2012-09-28     11    1227430.73             0        77.67       3.666
# 2012-10-05     11    1422794.26             0        73.37       3.617
# 2012-10-12     11    1311965.09             0        69.94       3.601
# 2012-10-19     11    1232073.18             0        73.77       3.594
# 2012-10-26     11    1200729.45             0        74.26       3.506
#
#                    CPI  Unemployment          Date  Poly_Trend  Poly_Resid
# Date
# 2010-02-05  214.424881         7.368  1.265328e+09    7.400698   -0.032698
# 2010-02-12  214.574792         7.368  1.265933e+09    7.387300   -0.019300
# 2010-02-19  214.619887         7.368  1.266538e+09    7.375380   -0.007380
# 2010-02-26  214.647513         7.368  1.267142e+09    7.364879    0.003121
# 2010-03-05  214.675139         7.368  1.267747e+09    7.355740    0.012260
# ...                ...           ...           ...         ...         ...
# 2012-09-28  226.518093         6.334  1.348790e+09    6.207661    0.126339
# 2012-10-05  226.721036         6.034  1.349395e+09    6.195185   -0.161185
# 2012-10-12  226.923979         6.034  1.350000e+09    6.183870   -0.149870
# 2012-10-19  226.968844         6.034  1.350605e+09    6.173773   -0.139773
# 2012-10-26  226.987364         6.034  1.351210e+09    6.164949   -0.130949
#
# [143 rows x 10 columns]

# %%
# Descomponer la serie temporal
import statsmodels.api as sm

descomposicion = sm.tsa.seasonal_decompose(
    df['Unemployment'],
    model='additive',
    period=48,
    extrapolate_trend=0,
    two_sided=False,
    )
fig = descomposicion.plot()
plt.show()

# %% [markdown]
# Dickey - Fuller aumentada

# %%
#Prueba de estacionariedad: Prueba de Dickey-Fuller aumentada (ADF)

#Hipótesis nula (H₀): La serie tiene una raíz unitaria (no es estacionaria).
#Hipótesis alternativa (H₁): La serie es estacionaria.

from statsmodels.tsa.stattools import adfuller

nivel_de_significancia = 0.05

# Realizar la prueba de Dickey-Fuller en los la tendencia
adf_test = adfuller(df['Poly_Resid'].dropna()) # Realiza la prueba ADF


# Interpretación de la prueba ADF
print('Estadístico ADF:', adf_test[0])
print('p-value:', adf_test[1])

if adf_test[1] <= nivel_de_significancia:
    print("La tendencia es estacionaria (rechazamos la hipótesis nula).")
else:
    print("La tendencia no es estacionaria (aceptamos la hipótesis nula).")
# Out:
# Estadístico ADF: -3.7721751255654685
# p-value: 0.003205179867786983
# La tendencia es estacionaria (rechazamos la hipótesis nula).
